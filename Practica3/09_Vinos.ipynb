# %%
FUENTES_DIR = '../Fuentes'         # carpeta donde se encuentran archivos .py auxiliares
DATOS_DIR   = '../Data_Sets/p3/' # carpeta donde se encuentran los datasets

# agrega ruta de busqueda donde tenemos archivos .py
import sys
sys.path.append(FUENTES_DIR)

# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pylab as plt
from IPython import display
from ClassPerceptron import Perceptron
from sklearn import preprocessing
import grafica as gr
from ClassNeuronaGral import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Ejercicio 9
#
# Se ha realizado un análisis químico a tres tipos distintos de vinos producidos en una misma región de Italia. El número de muestras considerado es el siguiente:
#
# $$
# 	\text{Tipo 1} \rightarrow 59~\text{muestras}, \quad\quad \text{Tipo 2} \rightarrow 71~\text{muestras}, \quad\quad \text{Tipo 3} \rightarrow 48~\text{muestras}
# $$
#
#
# El archivo **vinos.csv** permite observar los resultados de este análisis. Cada fila representa una muestra distinta y está formada, en primer lugar, por el número del tipo al cual pertenece el vino analizado, seguido por los 13 atributos que lo caracterizan.
#
# Por ejemplo, la siguiente fila:
#
# $$
# 	2, ~12.29, ~3.17, ~2.21, ~18, ~88, ~2.85, ~2.99, ~0.45, ~2.81, ~2.3, ~1.42, ~2.83, ~406
# $$
#
#
# es el resultado del análisis de un vino correspondiente al **tipo 2** (primer valor de la fila), seguido por 13 valores separados por comas que indican los niveles de las mediciones realizadas a dicho vino.
#
#
# ### a)
#
# Entrene una red neuronal formada por una única neurona para clasificar los vinos de **Tipo 1**.
#
# Realice **30 ejecuciones independientes** utilizando el **50%, 60%, 70%, 80% y 90%** de los ejemplos como entrenamiento y el resto como testeo. Para cada porcentaje, indique la cantidad promedio de ejemplos correctamente clasificados en entrenamiento y en testeo. Calcule también el promedio y el desvío de la cantidad de iteraciones realizadas.
#
# Utilice un máximo de 400 iteraciones y velocidades de aprendizaje 0.1, 0.2 y 0.3.
#
# Analice los resultados obtenidos utilizando:
# **i.** Función de activación ‘sigmoid’ y función de costo ‘ECM’ (error cuadrático medio)
# **ii.** Función de activación ‘sigmoid’ y función de costo ‘EC_binaria’ (entropía cruzada binaria)
# **iii.** Función de activación ‘tanh’ y función de costo ‘ECM’ (error cuadrático medio)

# %% [markdown]
# # *i* & *ii*

# %%
data = pd.read_csv(DATOS_DIR + 'Vinos.csv', sep= ';')
ejecuciones = 30
porcentajes = [0.5, 0.6, 0.7, 0.8, 0.9]
alphas = [0.1, 0.2, 0.3]
N_ITER = 400
COTA = 1e-4
# Separar atributos y clase
X = data.iloc[:, 1:].values          # 13 atributos
y = (data.iloc[:, 0].values == 1).astype(int)  # 1 si es tipo 1, 0 en caso contrario

# -------------------
# Estructura para guardar resultados
# -------------------
resultados = {}

for alpha in alphas:
    resultados[alpha] = {}
    for p in porcentajes:
        resultados[alpha][p] = []
        for rep in range(ejecuciones): 
            # split train / test
            X_train, X_test, y_train, y_test = train_test_split(
                X, y, train_size=p, shuffle=True
            )

            # entreno la neurona
            ng = ng = NeuronaGradiente(alpha=alpha, n_iter=N_ITER, cotaE=COTA, FUN='sigmoid')
            ng.fit(X_train, y_train)

            # predicciones
            y_pred = ng.predict(X_test)        # etiquetas binarias
            y_prob = ng.predict_nOut(X_test)   # salida sigmoidal

            # métricas
            accuracy = np.mean(y_pred == y_test)
            ecm = np.mean((y_prob - y_test) ** 2)
            eps = np.finfo(float).eps  # evitar log(0)
            cross_entropy = -np.mean(y_test * np.log(y_prob + eps) + (1 - y_test) * np.log(1 - y_prob + eps))
            resultados[alpha][p].append((accuracy, ecm, cross_entropy)) 

# impresión de resultados
for alpha in alphas:
    print(f"Resultados para alpha = {alpha}:")
    for p in porcentajes:
        acc_list  = [acc for acc, _, _ in resultados[alpha][p]]
        ecm_list  = [ecm for _, ecm, _ in resultados[alpha][p]]
        ce_list   = [ce  for _, _, ce in resultados[alpha][p]]

        print(f"  Porcentaje entrenamiento {int(p*100)}%:")
        print(f"    Accuracy -> Media = {np.mean(acc_list):.4f}, Desvío = {np.std(acc_list):.4f}")
        print(f"    ECM      -> Media = {np.mean(ecm_list):.6f}, Desvío = {np.std(ecm_list):.6f}")
        print(f"    CE bin   -> Media = {np.mean(ce_list):.6f}, Desvío = {np.std(ce_list):.6f}")
# Out:
# /home/manuel/Documents/Facultad/DeepLearning/Practica3/../Fuentes/ClassNeuronaGral.py:127: RuntimeWarning: overflow encountered in exp
#   return (1.0/(1+np.exp(-x)))
# Resultados para alpha = 0.1:
#   Porcentaje entrenamiento 50%:
#     Accuracy -> Media = 0.5213, Desvío = 0.1664
#     ECM      -> Media = 0.478652, Desvío = 0.166393
#     CE bin   -> Media = 17.249093, Desvío = 5.992512
#   Porcentaje entrenamiento 60%:
#     Accuracy -> Media = 0.5060, Desvío = 0.1704
#     ECM      -> Media = 0.493981, Desvío = 0.170356
#     CE bin   -> Media = 17.368900, Desvío = 5.846662
#   Porcentaje entrenamiento 70%:
#     Accuracy -> Media = 0.4463, Desvío = 0.1697
#     ECM      -> Media = 0.553704, Desvío = 0.169681
#     CE bin   -> Media = 19.491954, Desvío = 5.901981
#   Porcentaje entrenamiento 80%:
#     Accuracy -> Media = 0.4833, Desvío = 0.1635
#     ECM      -> Media = 0.516667, Desvío = 0.163488
#     CE bin   -> Media = 18.292783, Desvío = 5.892277
#   Porcentaje entrenamiento 90%:
#     Accuracy -> Media = 0.5352, Desvío = 0.1990
#     ECM      -> Media = 0.464815, Desvío = 0.199012
#     CE bin   -> Media = 16.669290, Desvío = 7.105748
# Resultados para alpha = 0.2:
#   Porcentaje entrenamiento 50%:
#     Accuracy -> Media = 0.5457, Desvío = 0.1646
#     ECM      -> Media = 0.454307, Desvío = 0.164616
#     CE bin   -> Media = 16.169997, Desvío = 6.014514
#   Porcentaje entrenamiento 60%:
#     Accuracy -> Media = 0.5065, Desvío = 0.1741
#     ECM      -> Media = 0.493519, Desvío = 0.174091
#     CE bin   -> Media = 17.678756, Desvío = 6.226312
#   Porcentaje entrenamiento 70%:
#     Accuracy -> Media = 0.4895, Desvío = 0.1654
#     ECM      -> Media = 0.510494, Desvío = 0.165406
#     CE bin   -> Media = 17.970816, Desvío = 5.941796
#   Porcentaje entrenamiento 80%:
#     Accuracy -> Media = 0.5213, Desvío = 0.1827
#     ECM      -> Media = 0.478704, Desvío = 0.182670
#     CE bin   -> Media = 17.058284, Desvío = 6.669820
#   Porcentaje entrenamiento 90%:
#     Accuracy -> Media = 0.5111, Desvío = 0.2056
#     ECM      -> Media = 0.488889, Desvío = 0.205581
#     CE bin   -> Media = 17.592041, Desvío = 7.378231
# Resultados para alpha = 0.3:
#   Porcentaje entrenamiento 50%:
#     Accuracy -> Media = 0.4978, Desvío = 0.1653
#     ECM      -> Media = 0.502247, Desvío = 0.165342
#     CE bin   -> Media = 17.942870, Desvío = 6.103722
#   Porcentaje entrenamiento 60%:
#     Accuracy -> Media = 0.5370, Desvío = 0.1654
#     ECM      -> Media = 0.462963, Desvío = 0.165363
#     CE bin   -> Media = 16.686877, Desvío = 5.960276
#   Porcentaje entrenamiento 70%:
#     Accuracy -> Media = 0.5364, Desvío = 0.1670
#     ECM      -> Media = 0.463580, Desvío = 0.166974
#     CE bin   -> Media = 16.251933, Desvío = 5.732486
#   Porcentaje entrenamiento 80%:
#     Accuracy -> Media = 0.5407, Desvío = 0.1785
#     ECM      -> Media = 0.459259, Desvío = 0.178548
#     CE bin   -> Media = 16.348898, Desvío = 6.257924
#   Porcentaje entrenamiento 90%:
#     Accuracy -> Media = 0.5574, Desvío = 0.1906
#     ECM      -> Media = 0.442593, Desvío = 0.190561
#     CE bin   -> Media = 15.952654, Desvío = 6.868510

# %% [markdown]
# # *iii*

# %%
y = np.where(data.iloc[:,0].values == 1, 1, -1)


resultados = {}

for alpha in alphas:
    resultados[alpha] = {}
    for p in porcentajes:
        resultados[alpha][p] = []
        for rep in range(ejecuciones): 
            # split train / test
            X_train, X_test, y_train, y_test = train_test_split(
                X, y, train_size=p, shuffle=True
            )

            # entreno la neurona
            ng = ng = NeuronaGradiente(alpha=alpha, n_iter=N_ITER, cotaE=COTA, FUN='tanh')
            ng.fit(X_train, y_train)

            # predicciones
            y_pred = ng.predict(X_test)        # etiquetas binarias
            y_prob = ng.predict_nOut(X_test)   # salida sigmoidal

            # métricas
            accuracy = np.mean(y_pred == y_test)
            ecm = np.mean((y_prob - y_test) ** 2)
            resultados[alpha][p].append((accuracy, ecm)) 

# impresión de resultados
for alpha in alphas:
    print(f"Resultados para alpha = {alpha}:")
    for p in porcentajes:
        acc_list  = [acc for acc, _ in resultados[alpha][p]]
        ecm_list  = [ecm for _, ecm in resultados[alpha][p]]

        print(f"  Porcentaje entrenamiento {int(p*100)}%:")
        print(f"    Accuracy -> Media = {np.mean(acc_list):.4f}, Desvío = {np.std(acc_list):.4f}")
        print(f"    ECM      -> Media = {np.mean(ecm_list):.6f}, Desvío = {np.std(ecm_list):.6f}")
# Out:
# /home/manuel/Documents/Facultad/DeepLearning/Practica3/../Fuentes/ClassNeuronaGral.py:125: RuntimeWarning: overflow encountered in exp
#   return (2.0 / (1+np.exp(-2*x)) - 1)
# Resultados para alpha = 0.1:
#   Porcentaje entrenamiento 50%:
#     Accuracy -> Media = 0.5120, Desvío = 0.1698
#     ECM      -> Media = 1.952060, Desvío = 0.679002
#   Porcentaje entrenamiento 60%:
#     Accuracy -> Media = 0.4773, Desvío = 0.1604
#     ECM      -> Media = 2.090741, Desvío = 0.641417
#   Porcentaje entrenamiento 70%:
#     Accuracy -> Media = 0.5543, Desvío = 0.1686
#     ECM      -> Media = 1.782716, Desvío = 0.674558
#   Porcentaje entrenamiento 80%:
#     Accuracy -> Media = 0.4963, Desvío = 0.1873
#     ECM      -> Media = 2.014815, Desvío = 0.749064
#   Porcentaje entrenamiento 90%:
#     Accuracy -> Media = 0.5019, Desvío = 0.2159
#     ECM      -> Media = 1.992593, Desvío = 0.863495
# Resultados para alpha = 0.2:
#   Porcentaje entrenamiento 50%:
#     Accuracy -> Media = 0.4708, Desvío = 0.1761
#     ECM      -> Media = 2.116854, Desvío = 0.704281
#   Porcentaje entrenamiento 60%:
#     Accuracy -> Media = 0.5620, Desvío = 0.1521
#     ECM      -> Media = 1.751852, Desvío = 0.608536
#   Porcentaje entrenamiento 70%:
#     Accuracy -> Media = 0.5611, Desvío = 0.1592
#     ECM      -> Media = 1.755556, Desvío = 0.636678
#   Porcentaje entrenamiento 80%:
#     Accuracy -> Media = 0.4991, Desvío = 0.2033
#     ECM      -> Media = 2.003704, Desvío = 0.813205
#   Porcentaje entrenamiento 90%:
#     Accuracy -> Media = 0.5111, Desvío = 0.1817
#     ECM      -> Media = 1.955556, Desvío = 0.726681
# Resultados para alpha = 0.3:
#   Porcentaje entrenamiento 50%:
#     Accuracy -> Media = 0.5255, Desvío = 0.1791
#     ECM      -> Media = 1.898127, Desvío = 0.716257
#   Porcentaje entrenamiento 60%:
#     Accuracy -> Media = 0.5639, Desvío = 0.1453
#     ECM      -> Media = 1.744444, Desvío = 0.581364
#   Porcentaje entrenamiento 70%:
#     Accuracy -> Media = 0.4537, Desvío = 0.1768
#     ECM      -> Media = 2.185185, Desvío = 0.707074
#   Porcentaje entrenamiento 80%:
#     Accuracy -> Media = 0.5491, Desvío = 0.1800
#     ECM      -> Media = 1.803704, Desvío = 0.719901
#   Porcentaje entrenamiento 90%:
#     Accuracy -> Media = 0.4796, Desvío = 0.2000
#     ECM      -> Media = 2.081481, Desvío = 0.800171
